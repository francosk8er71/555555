# %% [markdown]
# # Práctica 9. Ejercicio adicional 2: Sudoku. Parte I
#
# En este ejercicio adicional vamos a crear la primera parte de una aplicación que sea capaz de "observar" un Sudoku y resolverlo. En concreto en esta primera parte vamos a detectar el tablero del Sudoku, sus casillas y si dichas casillas están vacías o contienen un número (por el momento no identificaremos el número que contiene).
#
# Todos los tableros de Sudoku que utilizaremos en esta parte de la práctica han sido extraídos desde http://www.sudoku-online.org/imprimir-sudokus.php.
#
#
# Comenzamos cargando las librerías necesarias y definiendo la funcionalidad para mostrar imágenes.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import imutils
# %matplotlib inline 
# !wget www.unirioja.es/cu/joheras/ia/p9/imágenes.zip
# !unzip imágenes.zip
# Out:
# --2018-05-10 13:32:16--  http://www.unirioja.es/cu/joheras/ia/p9/im%C3%A1genes.zip
# Resolving www.unirioja.es (www.unirioja.es)... 193.144.2.30
# Connecting to www.unirioja.es (www.unirioja.es)|193.144.2.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282251 (276K) [application/zip]
# Saving to: ‘imágenes.zip’
#
# imágenes.zip        100%[===================>] 275.64K   121KB/s    in 2.3s
#
# 2018-05-10 13:32:19 (121 KB/s) - ‘imágenes.zip’ saved [282251/282251]
#
# Archive:  imágenes.zip
#    creating: imágenes/
#   inflating: imágenes/tornillos.png
#   inflating: imágenes/thresh.png
#   inflating: imágenes/sudoku3.png
#   inflating: imágenes/sudoku2.png
#   inflating: imágenes/tetris_blocks.png
#   inflating: imágenes/more_shapes.png
#   inflating: imágenes/sudoku1.png
#   inflating: imágenes/contours_convex_hull.jpg
#   inflating: imágenes/basic_shapes.png
#   inflating: imágenes/contours_tictactoe.png
#   inflating: imágenes/playa-paraiso.jpg
#   inflating: imágenes/gato.jpg
#   inflating: imágenes/ur.jpeg

# %%
def mostrarImagen(image):
    if len(image.shape)==3:
        img2 = image[:,:,::-1]
        plt.imshow(img2)
        plt.show()
    else:
        img2 = image
        plt.imshow(img2,cmap='gray')
        plt.show()

# %% [markdown]
# A continuación cargamos una imagen de un tablero de Sudoku.

# %%
sudoku1 = cv2.imread("imágenes/sudoku1.png")
mostrarImagen(sudoku1)

# %% [markdown]
# A continuación debes implementar la funcionalidad para detectar las casillas del Sudoku siguiendo los siguientes pasos.
#
# Comienza clonando la imagen del Sudoku.

# %%
sudokuClone = sudoku1.copy()

# %% [markdown]
# Transforma la imagen del Sudoku a escala de grises.

# %%
graySudoku = cv2.cvtColor(sudokuClone, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# Umbraliza la imagen utilizando como valor de umbral 30.

# %%
threshSudoku = cv2.threshold(graySudoku, 30, 255, cv2.THRESH_BINARY_INV)[1]

# %% [markdown]
# Localiza los contornos en la imagen umbralizada, pero en lugar de usar el método `cv2.RETR_EXTERNAL` utiliza el método `cv2.RETR_LIST` esto te permitirá encontrar los contornos internos y externos de la imagen.

# %%
_,cnts,_ = cv2.findContours(graySudoku.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# Muestra los contornos de la imagen y sus propiedades. El objetivo es encontrar las casillas del tablero, para descartar aquellos elementos del tablero que no son casillas puedes tener en cuenta que la solidity y el aspect ratio de las casillas debe tener un valor cercano a 1; además las casillas han de tener un área mínima (que te permitirá descartar objetos) y un área máxima (no queremos detectar el tablero).
#
# Casillas, perimetro [150, 160]

# %%
clone = sudoku1.copy()
for (i, c) in enumerate(cnts):
    cv2.drawContours(clone, [c], -1, (0, 255, 0), 2)
    mostrarImagen(clone)

# %%
clone = sudoku1.copy()
for (i, c) in enumerate(cnts):
    area = cv2.contourArea(c)
    perimetro = cv2.arcLength(c, True)
    area = cv2.contourArea(c)
    (x, y, w, h) = cv2.boundingRect(c)
    aspectRatio = w / float(h)
    extent = area / float(w * h)
    hull = cv2.convexHull(c)
    hullArea = cv2.contourArea(hull)
    solidity = area / float(hullArea)
    print("Contorno #{} -- area: {:.2f}, -- perimetro: {:.2f} -- solidity={:.2f} -- area={:.2f} -- aspectRatio={:.2f} -- extent={:.2f} -- hullArea={:.2f}".
          format(i + 1, area, perimetro, solidity,area,aspectRatio,extent,hullArea))
 
    cv2.drawContours(clone, [c], -1, (0, 255, 0), 2)
 
    # Dibujamos el identificador de cada contorno
    M = cv2.moments(c)
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
    cv2.putText(clone, "#{}".format(i + 1), (cX - 20, cY), cv2.FONT_HERSHEY_SIMPLEX, 1.25, (255, 255, 255), 4)
mostrarImagen(clone)
# Out:
# Contorno #1 -- area: 22.00, -- perimetro: 24.97 -- solidity=0.67 -- area=22.00 -- aspectRatio=1.29 -- extent=0.35 -- hullArea=33.00
# Contorno #2 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #3 -- area: 56.00, -- perimetro: 51.46 -- solidity=0.74 -- area=56.00 -- aspectRatio=1.00 -- extent=0.46 -- hullArea=76.00
# Contorno #4 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #5 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #6 -- area: 22.00, -- perimetro: 25.31 -- solidity=0.83 -- area=22.00 -- aspectRatio=0.42 -- extent=0.37 -- hullArea=26.50
# Contorno #7 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #8 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #9 -- area: 20.00, -- perimetro: 17.66 -- solidity=0.95 -- area=20.00 -- aspectRatio=1.00 -- extent=0.56 -- hullArea=21.00
# Contorno #10 -- area: 9.00, -- perimetro: 12.49 -- solidity=0.95 -- area=9.00 -- aspectRatio=0.67 -- extent=0.38 -- hullArea=9.50
# Contorno #11 -- area: 20.50, -- perimetro: 23.90 -- solidity=0.73 -- area=20.50 -- aspectRatio=1.00 -- extent=0.32 -- hullArea=28.00
# Contorno #12 -- area: 83.00, -- perimetro: 37.80 -- solidity=0.92 -- area=83.00 -- aspectRatio=0.85 -- extent=0.58 -- hullArea=90.50
# Contorno #13 -- area: 69.00, -- perimetro: 67.60 -- solidity=0.55 -- area=69.00 -- aspectRatio=0.56 -- extent=0.38 -- hullArea=125.50
# Contorno #14 -- area: 73.00, -- perimetro: 52.14 -- solidity=0.65 -- area=73.00 -- aspectRatio=0.61 -- extent=0.37 -- hullArea=113.00
# Contorno #15 -- area: 34.00, -- perimetro: 28.49 -- solidity=0.80 -- area=34.00 -- aspectRatio=1.57 -- extent=0.44 -- hullArea=42.50
# Contorno #16 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #17 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #18 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #19 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #20 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #21 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #22 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #23 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #24 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #25 -- area: 22.00, -- perimetro: 24.97 -- solidity=0.67 -- area=22.00 -- aspectRatio=1.29 -- extent=0.35 -- hullArea=33.00
# Contorno #26 -- area: 38.00, -- perimetro: 32.14 -- solidity=0.80 -- area=38.00 -- aspectRatio=1.38 -- extent=0.43 -- hullArea=47.50
# Contorno #27 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #28 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #29 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #30 -- area: 22.00, -- perimetro: 25.31 -- solidity=0.83 -- area=22.00 -- aspectRatio=0.42 -- extent=0.37 -- hullArea=26.50
# Contorno #31 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #32 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #33 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #34 -- area: 20.00, -- perimetro: 17.66 -- solidity=0.95 -- area=20.00 -- aspectRatio=1.00 -- extent=0.56 -- hullArea=21.00
# Contorno #35 -- area: 31.00, -- perimetro: 33.80 -- solidity=0.61 -- area=31.00 -- aspectRatio=1.11 -- extent=0.34 -- hullArea=51.00
# Contorno #36 -- area: 34.00, -- perimetro: 28.49 -- solidity=0.80 -- area=34.00 -- aspectRatio=1.57 -- extent=0.44 -- hullArea=42.50
# Contorno #37 -- area: 73.00, -- perimetro: 52.14 -- solidity=0.65 -- area=73.00 -- aspectRatio=0.61 -- extent=0.37 -- hullArea=113.00
# Contorno #38 -- area: 83.00, -- perimetro: 37.80 -- solidity=0.92 -- area=83.00 -- aspectRatio=0.85 -- extent=0.58 -- hullArea=90.50
# Contorno #39 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #40 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #41 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #42 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #43 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #44 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #45 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #46 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #47 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #48 -- area: 21.50, -- perimetro: 17.07 -- solidity=1.00 -- area=21.50 -- aspectRatio=1.00 -- extent=0.60 -- hullArea=21.50
# Contorno #49 -- area: 22.00, -- perimetro: 25.31 -- solidity=0.83 -- area=22.00 -- aspectRatio=0.42 -- extent=0.37 -- hullArea=26.50
# Contorno #50 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #51 -- area: 56.00, -- perimetro: 55.11 -- solidity=0.61 -- area=56.00 -- aspectRatio=0.79 -- extent=0.36 -- hullArea=92.00
# Contorno #52 -- area: 84.50, -- perimetro: 41.21 -- solidity=0.88 -- area=84.50 -- aspectRatio=0.73 -- extent=0.51 -- hullArea=96.00
# Contorno #53 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #54 -- area: 11.50, -- perimetro: 15.07 -- solidity=0.88 -- area=11.50 -- aspectRatio=1.75 -- extent=0.41 -- hullArea=13.00
# Contorno #55 -- area: 34.00, -- perimetro: 28.49 -- solidity=0.80 -- area=34.00 -- aspectRatio=1.57 -- extent=0.44 -- hullArea=42.50
# Contorno #56 -- area: 20.50, -- perimetro: 19.07 -- solidity=0.91 -- area=20.50 -- aspectRatio=1.60 -- extent=0.51 -- hullArea=22.50
# Contorno #57 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #58 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #59 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #60 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #61 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #62 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #63 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #64 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #65 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #66 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #67 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #68 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #69 -- area: 69.00, -- perimetro: 67.60 -- solidity=0.55 -- area=69.00 -- aspectRatio=0.56 -- extent=0.38 -- hullArea=125.50
# Contorno #70 -- area: 73.00, -- perimetro: 52.14 -- solidity=0.65 -- area=73.00 -- aspectRatio=0.61 -- extent=0.37 -- hullArea=113.00
# Contorno #71 -- area: 1520.50, -- perimetro: 155.41 -- solidity=1.00 -- area=1520.50 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1520.50
# Contorno #72 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #73 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #74 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #75 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #76 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #77 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #78 -- area: 1520.50, -- perimetro: 155.41 -- solidity=1.00 -- area=1520.50 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1520.50
# Contorno #79 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #80 -- area: 22.00, -- perimetro: 24.97 -- solidity=0.67 -- area=22.00 -- aspectRatio=1.29 -- extent=0.35 -- hullArea=33.00
# Contorno #81 -- area: 38.00, -- perimetro: 32.14 -- solidity=0.80 -- area=38.00 -- aspectRatio=1.38 -- extent=0.43 -- hullArea=47.50
# Contorno #82 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #83 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #84 -- area: 56.00, -- perimetro: 51.46 -- solidity=0.74 -- area=56.00 -- aspectRatio=1.00 -- extent=0.46 -- hullArea=76.00
# Contorno #85 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #86 -- area: 56.00, -- perimetro: 55.11 -- solidity=0.61 -- area=56.00 -- aspectRatio=0.79 -- extent=0.36 -- hullArea=92.00
# Contorno #87 -- area: 9.00, -- perimetro: 12.49 -- solidity=0.95 -- area=9.00 -- aspectRatio=0.67 -- extent=0.38 -- hullArea=9.50
# Contorno #88 -- area: 20.00, -- perimetro: 17.66 -- solidity=0.95 -- area=20.00 -- aspectRatio=1.00 -- extent=0.56 -- hullArea=21.00
# Contorno #89 -- area: 31.00, -- perimetro: 33.80 -- solidity=0.61 -- area=31.00 -- aspectRatio=1.11 -- extent=0.34 -- hullArea=51.00
# Contorno #90 -- area: 20.50, -- perimetro: 23.90 -- solidity=0.73 -- area=20.50 -- aspectRatio=1.00 -- extent=0.32 -- hullArea=28.00
# Contorno #91 -- area: 69.00, -- perimetro: 67.60 -- solidity=0.55 -- area=69.00 -- aspectRatio=0.56 -- extent=0.38 -- hullArea=125.50
# Contorno #92 -- area: 83.00, -- perimetro: 37.80 -- solidity=0.92 -- area=83.00 -- aspectRatio=0.85 -- extent=0.58 -- hullArea=90.50
# Contorno #93 -- area: 20.50, -- perimetro: 19.07 -- solidity=0.91 -- area=20.50 -- aspectRatio=1.60 -- extent=0.51 -- hullArea=22.50
# Contorno #94 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #95 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #96 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #97 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #98 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #99 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #100 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #101 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #102 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #103 -- area: 21.50, -- perimetro: 17.07 -- solidity=1.00 -- area=21.50 -- aspectRatio=1.00 -- extent=0.60 -- hullArea=21.50
# Contorno #104 -- area: 56.00, -- perimetro: 51.46 -- solidity=0.74 -- area=56.00 -- aspectRatio=1.00 -- extent=0.46 -- hullArea=76.00
# Contorno #105 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #106 -- area: 84.50, -- perimetro: 41.21 -- solidity=0.88 -- area=84.50 -- aspectRatio=0.73 -- extent=0.51 -- hullArea=96.00
# Contorno #107 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #108 -- area: 9.00, -- perimetro: 12.49 -- solidity=0.95 -- area=9.00 -- aspectRatio=0.67 -- extent=0.38 -- hullArea=9.50
# Contorno #109 -- area: 11.50, -- perimetro: 15.07 -- solidity=0.88 -- area=11.50 -- aspectRatio=1.75 -- extent=0.41 -- hullArea=13.00
# Contorno #110 -- area: 20.50, -- perimetro: 23.90 -- solidity=0.73 -- area=20.50 -- aspectRatio=1.00 -- extent=0.32 -- hullArea=28.00
# Contorno #111 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #112 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #113 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #114 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #115 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #116 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #117 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #118 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #119 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #120 -- area: 22.00, -- perimetro: 24.97 -- solidity=0.67 -- area=22.00 -- aspectRatio=1.29 -- extent=0.35 -- hullArea=33.00
# Contorno #121 -- area: 21.50, -- perimetro: 17.07 -- solidity=1.00 -- area=21.50 -- aspectRatio=1.00 -- extent=0.60 -- hullArea=21.50
# Contorno #122 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #123 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #124 -- area: 22.00, -- perimetro: 25.31 -- solidity=0.83 -- area=22.00 -- aspectRatio=0.42 -- extent=0.37 -- hullArea=26.50
# Contorno #125 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #126 -- area: 56.00, -- perimetro: 55.11 -- solidity=0.61 -- area=56.00 -- aspectRatio=0.79 -- extent=0.36 -- hullArea=92.00
# Contorno #127 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #128 -- area: 84.50, -- perimetro: 41.21 -- solidity=0.88 -- area=84.50 -- aspectRatio=0.73 -- extent=0.51 -- hullArea=96.00
# Contorno #129 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #130 -- area: 20.00, -- perimetro: 17.66 -- solidity=0.95 -- area=20.00 -- aspectRatio=1.00 -- extent=0.56 -- hullArea=21.00
# Contorno #131 -- area: 11.50, -- perimetro: 15.07 -- solidity=0.88 -- area=11.50 -- aspectRatio=1.75 -- extent=0.41 -- hullArea=13.00
# Contorno #132 -- area: 20.50, -- perimetro: 19.07 -- solidity=0.91 -- area=20.50 -- aspectRatio=1.60 -- extent=0.51 -- hullArea=22.50
# Contorno #133 -- area: 73.00, -- perimetro: 52.14 -- solidity=0.65 -- area=73.00 -- aspectRatio=0.61 -- extent=0.37 -- hullArea=113.00
# Contorno #134 -- area: 83.00, -- perimetro: 37.80 -- solidity=0.92 -- area=83.00 -- aspectRatio=0.85 -- extent=0.58 -- hullArea=90.50
# Contorno #135 -- area: 34.00, -- perimetro: 28.49 -- solidity=0.80 -- area=34.00 -- aspectRatio=1.57 -- extent=0.44 -- hullArea=42.50
# Contorno #136 -- area: 69.00, -- perimetro: 67.60 -- solidity=0.55 -- area=69.00 -- aspectRatio=0.56 -- extent=0.38 -- hullArea=125.50
# Contorno #137 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #138 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #139 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #140 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #141 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #142 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #143 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #144 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #145 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #146 -- area: 22.00, -- perimetro: 25.31 -- solidity=0.83 -- area=22.00 -- aspectRatio=0.42 -- extent=0.37 -- hullArea=26.50
# Contorno #147 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #148 -- area: 34.00, -- perimetro: 28.49 -- solidity=0.80 -- area=34.00 -- aspectRatio=1.57 -- extent=0.44 -- hullArea=42.50
# Contorno #149 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #150 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #151 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #152 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #153 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #154 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #155 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #156 -- area: 1521.00, -- perimetro: 156.00 -- solidity=1.00 -- area=1521.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1521.00
# Contorno #157 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=0.97 -- extent=0.95 -- hullArea=1482.00
# Contorno #158 -- area: 38.00, -- perimetro: 32.14 -- solidity=0.80 -- area=38.00 -- aspectRatio=1.38 -- extent=0.43 -- hullArea=47.50
# Contorno #159 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #160 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #161 -- area: 21.50, -- perimetro: 17.07 -- solidity=1.00 -- area=21.50 -- aspectRatio=1.00 -- extent=0.60 -- hullArea=21.50
# Contorno #162 -- area: 84.50, -- perimetro: 41.21 -- solidity=0.88 -- area=84.50 -- aspectRatio=0.73 -- extent=0.51 -- hullArea=96.00
# Contorno #163 -- area: 2.00, -- perimetro: 5.66 -- solidity=1.00 -- area=2.00 -- aspectRatio=1.00 -- extent=0.22 -- hullArea=2.00
# Contorno #164 -- area: 31.00, -- perimetro: 33.80 -- solidity=0.61 -- area=31.00 -- aspectRatio=1.11 -- extent=0.34 -- hullArea=51.00
# Contorno #165 -- area: 11.50, -- perimetro: 15.07 -- solidity=0.88 -- area=11.50 -- aspectRatio=1.75 -- extent=0.41 -- hullArea=13.00
# Contorno #166 -- area: 69.00, -- perimetro: 67.60 -- solidity=0.55 -- area=69.00 -- aspectRatio=0.56 -- extent=0.38 -- hullArea=125.50
# Contorno #167 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #168 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #169 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #170 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #171 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #172 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #173 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #174 -- area: 1482.00, -- perimetro: 154.00 -- solidity=1.00 -- area=1482.00 -- aspectRatio=1.03 -- extent=0.95 -- hullArea=1482.00
# Contorno #175 -- area: 1444.00, -- perimetro: 152.00 -- solidity=1.00 -- area=1444.00 -- aspectRatio=1.00 -- extent=0.95 -- hullArea=1444.00
# Contorno #176 -- area: 137639.00, -- perimetro: 1481.66 -- solidity=1.00 -- area=137639.00 -- aspectRatio=1.00 -- extent=0.99 -- hullArea=137639.00
# Contorno #177 -- area: 137641.00, -- perimetro: 1484.00 -- solidity=1.00 -- area=137641.00 -- aspectRatio=1.00 -- extent=0.99 -- hullArea=137641.00

# %% [markdown]
# Una vez has detectado los contornos de las casillas, debes darte cuenta de que dichos contornos no están ordenados (en ocasiones anteriores el orden no era importante, pero ahora sí que lo es). Para ordenar los contornos de izquierda a derecha y de arriba a abajo puedes utilizar la siguiente función.

# %%
def sort_contours(cnts):
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),key=lambda b:(b[1][1],b[1][0]), reverse=False))
    return cnts

# %% [markdown]
# Utiliza la función anterior para ordenar los contornos de las casillas.

# %%
cnts = sort_contours(cnts)

# %% [markdown]
# Pasamos ahora a determinar si una casilla contiene un número dentro. Para ello primero define una función que dada una imagen, compruebe si la imagen es completamente blanca (es decir todos sus píxeles tienen valor igual a 255), si dicha lista es vacía devuelve el carácter '.' en caso contrario devuelve el carácter '?' (recuerda que esta era la notación que usabamos en la práctica 4 para representar los sudokus).

# %%
import numpy as np

def casillaVacia(image):
  for i in range(0, image.shape[0]):
    for j in range(0, image.shape[1]):
      if(image[i, j] != (255, 255, 255)):
        return '?'
  return '.'

def casillaVacia2(image):
  imageGray = cv2.cvtColor(image.copy(),cv2.COLOR_BGR2GRAY)
  inversa = cv2.bitwise_not(imageGray)
  if(np.sum(inversa) == 0):
    return '.'
  else:
    return '?'

# %% [markdown]
# A continuación debes recortar cada uno de los contornos de las casillas de la imagen del Sudoku y pasárselo a la función anterior.

# %% [markdown]
# Finalmente define una función que a partir de cualquier del path de cualquier imagen de Sudoku sea capaz de extraer el tablero con la notación dada. Comprueba que los resultados son los esperados.

# %%
def generaTablero(imagenPath):
    ???

# %%
generaTablero("imágenes/sudoku1.png")

# %%
generaTablero("imágenes/sudoku2.png")

# %%
generaTablero("imágenes/sudoku3.png")
