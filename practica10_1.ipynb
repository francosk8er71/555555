# %% [markdown]
# # Práctica 10. Ejercicio adicional 1: Sudoku. Parte II.
#
# Este notebook es el menos guiado de la asignatura. El objetivo es combinar todo lo que hemos visto a lo largo del curso para leer un Sudoku y resolverlo. Para ello necesitarás los ejercicios adicionales de las prácticas 9 y 4.
